# %%
#imported all the Library and given short name
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file
data= pd.read_csv("House Price India.csv")

# %%
#seeing csv data
data
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
#seeing the info of the csv
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
#  10  grade of the house                     14619 non-null  int64
# ...

# %%
#cleaning the data
data.dropna(inplace=True)

# %%
#after cleaning data
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
#  10  grade of the house                     14619 non-null  int64
# ...

# %%
#Split your data into training data and testing data
from sklearn.model_selection import train_test_split

X = data.drop(['Price', 'id'], axis=1)
y = data['Price']

# %%
#seeing the data after split
y.head()
# Out:
# 0    1400000
# 1    1200000
# 2     838000
# 3     805000
# 4     790000
# Name: Price, dtype: int64

# %%
#seeing the data after split
X.head()
# Out:
#     Date  number of bedrooms  number of bathrooms  living area  lot area  \
# 0  42491                   4                 2.50         2920      4000
# 1  42491                   5                 2.75         2910      9480
# 2  42491                   4                 2.50         3310     42998
# 3  42491                   3                 2.00         2710      4500
# 4  42491                   3                 2.50         2600      4750
#
#    number of floors  waterfront present  number of views  \
# 0               1.5                   0                0
# 1               1.5                   0                0
# 2               2.0                   0                0
# 3               1.5                   0                0
# 4               1.0                   0                0
#
#    condition of the house  grade of the house  ...  Area of the basement  \
# 0                       5                   8  ...                  1010
# ...

# %%
#splits your data into 2 parts Training data,Testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, #80% → Training data, 20% → Testing data
    random_state=42 #Split the data in the same way every time
)

# %%
X_train.shape
# Out:
# (11695, 21)

# %%
X_test.shape
# Out:
# (2924, 21)

# %%
y_train.shape
# Out:
# (11695,)

# %%
y_test.shape
# Out:
# (2924,)

# %%
#creating a new empty brain
from sklearn.linear_model import LinearRegression

model = LinearRegression() #creating a model object
model.fit(X_train, y_train) #This is where learning happens
# Out:
# LinearRegression()

# %%
#Check how good my model is using test data
score = model.score(X_test, y_test)
print(score)
# Out:
# 0.7019654586300896

# %%
#for raw output 
model.predict(X_test[:1])
# Out:
# array([540991.87175712])

# %%
#for clear output 
pred_price = model.predict(X_test[:1])[0]
print(f"Predicted Price: {round(pred_price)}")
# Out:
# Predicted Price: 540992

# %%
#Predict prices for ALL test houses
y_pred = model.predict(X_test)

# %%
#Compare real vs predicted
import pandas as pd

comparison = pd.DataFrame({
    "Actual Price": y_test.values,
    "Predicted Price": y_pred
})

comparison.head()
# Out:
#    Actual Price  Predicted Price
# 0        546800    540991.871757
# 1        550000    495092.151349
# 2        399950    542749.253642
# 3        940000    822030.531005
# 4        545000    734778.817990

# %%
#Measure ERROR
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 125366.17937449114

# %%
#Root Mean Squared Error
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(rmse)
# Out:
# 210018.90705590323

# %%
#Visualize errors
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %%
#Check accuracy
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
#Check accuracy
rf_score = rf_model.score(X_test, y_test)
print(rf_score)
# Out:
# 0.8828279762600915

# %%
#Predict again
y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred_rf)
print(mae)
# Out:
# 69448.10885943913

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred_rf))
print(rmse)
# Out:
# 131685.22777361525

# %%
#Visual error understanding
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred_rf)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %%
#imaginary house written in the SAME format as your training data, so the model can predict its price.
import pandas as pd

custom_house = pd.DataFrame([{
    'number of bedrooms': 3,
    'number of bathrooms': 2,
    'living area': 1800,
    'lot area': 3000,
    'number of floors': 2,
    'waterfront present': 0,
    'number of views': 2,
    'condition of the house': 4,
    'grade of the house': 7,
    'Area of the house(excluding basement)': 1800,
    'Area of the basement': 400,
    'Built Year': 2015,
    'Renovation Year': 0,
    'Postal Code': 560001,
    'Lattitude': 12.97,
    'Longitude': 77.59,
    'living_area_renov': 0,
    'lot_area_renov': 0,
    'Number of schools nearby': 3,
    'Distance from the airport': 15
}])

# %%
#To ensure column order matches training data
custom_house = custom_house.reindex(columns=X_train.columns, fill_value=0)

# %%
#Predict custom price
custom_price = rf_model.predict(custom_house)[0]
print(f"Predicted House Price: ₹{round(custom_price)}")
# Out:
# Predicted House Price: ₹345796
